# %%
import joblib

# Load the model using joblib instead of pickle
loaded_model = joblib.load('C:/Users/91637/OneDrive/Desktop/project/face recognition/static/face_recognition_model.pkl')
print(loaded_model)
# Out:
# KNeighborsClassifier()
# C:\Users\91637\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.4.1.post1 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
loaded_model.weights
# Out:
# 'uniform'

# %%
# Out:
# u: shape u
# n: shape n
# i: shape i
# f: shape f
# o: shape o
# r: shape r
# m: shape m
